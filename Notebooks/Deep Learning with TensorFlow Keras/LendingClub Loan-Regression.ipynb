# %% [markdown]
# # Lending Club Loan Dataset
#
# This project performs a regression task on the LendingClub loan dataset.
#
# ## The Data
#
# LendingClub DataSet obtained from Kaggle: https://www.kaggle.com/wordsforthewise/lending-club
#
# LendingClub is a US peer-to-peer lending company, headquartered in San Francisco, California.[3] It was the first peer-to-peer lender to register its offerings as securities with the Securities and Exchange Commission (SEC), and to offer loan trading on a secondary market. LendingClub is the world's largest peer-to-peer lending platform.
#
# ### Our Goal
#
# Given historical data on loans given out with information on whether or not the borrower defaulted (charge-off), can it be predicted weather or not a borrower will pay back their loan? This way in the future when we get a new potential customer we can assess whether or not they are likely to pay back the loan.
#
#
# ### Data Overview
#
#
# There are many LendingClub data sets on Kaggle. Here is the information on this particular data set:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LoanStatNew</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>loan_amnt</td>
#       <td>The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>term</td>
#       <td>The number of payments on the loan. Values are in months and can be either 36 or 60.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>int_rate</td>
#       <td>Interest Rate on the loan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>installment</td>
#       <td>The monthly payment owed by the borrower if the loan originates.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>grade</td>
#       <td>LC assigned loan grade</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>sub_grade</td>
#       <td>LC assigned loan subgrade</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>emp_title</td>
#       <td>The job title supplied by the Borrower when applying for the loan.*</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>emp_length</td>
#       <td>Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>home_ownership</td>
#       <td>The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>annual_inc</td>
#       <td>The self-reported annual income provided by the borrower during registration.</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>verification_status</td>
#       <td>Indicates if income was verified by LC, not verified, or if the income source was verified</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>issue_d</td>
#       <td>The month which the loan was funded</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>loan_status</td>
#       <td>Current status of the loan</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>purpose</td>
#       <td>A category provided by the borrower for the loan request.</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>title</td>
#       <td>The loan title provided by the borrower</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>zip_code</td>
#       <td>The first 3 numbers of the zip code provided by the borrower in the loan application.</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>addr_state</td>
#       <td>The state provided by the borrower in the loan application</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>dti</td>
#       <td>A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>earliest_cr_line</td>
#       <td>The month the borrower's earliest reported credit line was opened</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>open_acc</td>
#       <td>The number of open credit lines in the borrower's credit file.</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>pub_rec</td>
#       <td>Number of derogatory public records</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>revol_bal</td>
#       <td>Total credit revolving balance</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>revol_util</td>
#       <td>Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>total_acc</td>
#       <td>The total number of credit lines currently in the borrower's credit file</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>initial_list_status</td>
#       <td>The initial listing status of the loan. Possible values are – W, F</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>application_type</td>
#       <td>Indicates whether the loan is an individual application or a joint application with two co-borrowers</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>mort_acc</td>
#       <td>Number of mortgage accounts.</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>pub_rec_bankruptcies</td>
#       <td>Number of public record bankruptcies</td>
#     </tr>
#   </tbody>
# </table>
#
# ---

# %% [markdown]
# ## 1. Data Import and Library Setup
#
# ### 1.1 Importing Libraries

# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# might be needed depending on your version of Jupyter
# %matplotlib inline

# %% [markdown]
# ### 1.2 Loading the Dataset

# %%
df = pd.read_csv('../DATA/lending_club_loan_two.csv')

# %% [markdown]
# ### 1.3 Initial Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
df.describe()
# Out:
#            loan_amnt       int_rate    installment    annual_inc  \
# count  396030.000000  396030.000000  396030.000000  3.960300e+05
# mean    14113.888089      13.639400     431.849698  7.420318e+04
# std      8357.441341       4.472157     250.727790  6.163762e+04
# min       500.000000       5.320000      16.080000  0.000000e+00
# 25%      8000.000000      10.490000     250.330000  4.500000e+04
# 50%     12000.000000      13.330000     375.430000  6.400000e+04
# 75%     20000.000000      16.490000     567.300000  9.000000e+04
# max     40000.000000      30.990000    1533.810000  8.706582e+06
#
#                  dti       open_acc        pub_rec     revol_bal  \
# count  396030.000000  396030.000000  396030.000000  3.960300e+05
# mean       17.379514      11.311153       0.178191  1.584454e+04
# std        18.019092       5.137649       0.530671  2.059184e+04
# min         0.000000       0.000000       0.000000  0.000000e+00
# ...

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     318357
# Charged Off     77673
# Name: count, dtype: int64

# %%
data_info = pd.read_csv('../DATA/lending_club_info.csv',index_col='LoanStatNew')

# %%
print(data_info.loc['revol_util']['Description'])
# Out:
# Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.

# %%
def feat_info(col_name):
    print(data_info.loc[col_name]['Description'])

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %% [markdown]
# ------
#
# ## 2 Exploratory Data Analysis

# %% [markdown]
# ### 2.1 Distribution of Loan Status
#
# **Count plot of loan status distribution**

# %%
sns.countplot(data=df, x='loan_status', orient='v', palette='coolwarm', hue='loan_status')
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %% [markdown]
# ### 2.2 Distribution based on loan amount.

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='loan_amnt', bins=40)
# Out:
# <Axes: xlabel='loan_amnt', ylabel='Count'>

# %% [markdown]
# **Checking outliers**

# %%
df[df['loan_amnt'] > 35000]
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 3998      40000.0   60 months     22.45      1115.02     E        E5
# 4788      40000.0   60 months      8.39       818.55     B        B1
# 5231      36225.0   36 months     20.75      1360.14     E        E2
# 6093      38225.0   36 months     25.69      1533.81     F        F1
# 7456      40000.0   36 months     15.59      1398.20     C        C5
# ...           ...         ...       ...          ...   ...       ...
# 388146    40000.0   60 months     19.99      1059.54     D        D4
# 388675    40000.0   36 months      9.75      1286.00     B        B3
# 392021    36000.0   36 months     16.29      1270.82     D        D1
# 393914    40000.0   60 months     12.99       909.92     C        C2
# 394927    37500.0   36 months     11.47      1236.07     B        B5
#
#                                    emp_title emp_length home_ownership  \
# ...

# %% [markdown]
# ### 2.3 Scatter plot between Installment and Loan Amount.

# %%
sns.scatterplot(data=df, x='installment', y='loan_amnt')
# Out:
# <Axes: xlabel='installment', ylabel='loan_amnt'>

# %%
print('"Installment" feature in the data represents:')
feat_info('installment')
print('-' * 100)
print('"Loan_amnt" feature in the data represents:')
feat_info('loan_amnt')
# Out:
# "Installment" feature in the data represents:
# The monthly payment owed by the borrower if the loan originates.
# ----------------------------------------------------------------------------------------------------
# "Loan_amnt" feature in the data represents:
# The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.

# %% [markdown]
# ### 2.4 Numerical Data Correlation

# %%
df_corr = pd.DataFrame(df)
df_corr['loan_status'] = df_corr['loan_status'].apply(lambda x: 1 if x == 'Fully Paid' else 0)
df_corr = df_corr.select_dtypes(exclude='object').corr()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_corr, annot=True, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### 2.5 Box plot b/w Loan status and Loan amount

# %%
sns.boxplot(data=df, x="loan_status", y="loan_amnt", hue='loan_status', palette="coolwarm")
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>

# %% [markdown]
# #### 2.5.1 Statistical Analysis of Loan status in relation to Loan amount.
#
# Tells the quantative numbers of column: 'loan_amt' and 'loan_status' relationship

# %%
df.groupby('loan_status')['loan_amnt'].describe()
# Out:
#                 count          mean          std     min     25%      50%  \
# loan_status
# Charged Off   77673.0  15126.300967  8505.090557  1000.0  8525.0  14000.0
# Fully Paid   318357.0  13866.878771  8302.319699   500.0  7500.0  12000.0
#
#                  75%      max
# loan_status
# Charged Off  20000.0  40000.0
# Fully Paid   19225.0  40000.0

# %% [markdown]
# ### 2.6 Count plot of 'grade', based on 'loan status' column

# %%
sns.countplot(data=df, x='grade', hue='loan_status')
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %% [markdown]
# ### 2.7 Relationships with 'sub-grades'

# %% [markdown]
# #### 2.7.1 Count plot of 'sub-grades'

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df, x='sub_grade', palette='coolwarm', hue='sub_grade', order=df['sub_grade'].sort_values().unique().tolist())
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %% [markdown]
# #### 2.7.2 Count plot of 'sub-grade', based on 'loan status' column

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df, x='sub_grade', hue='loan_status', palette='coolwarm', order=df['sub_grade'].sort_values().unique().tolist())
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
sub_grade_df = df[df['sub_grade'].str.startswith("F") | df['sub_grade'].str.startswith("G")]
plt.figure(figsize=(10,4))
sns.countplot(data=sub_grade_df, x='sub_grade', hue='loan_status', palette='coolwarm', order=sub_grade_df['sub_grade'].sort_values().unique().tolist())
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %% [markdown]
# ### 2.6 Correlation of Numerical data with 'Loan status'

# %%
df['loan_repaid'] = df['loan_status'].map({"Fully Paid": 1, 'Charged Off': 0})

# %% [markdown]
# Utilizing previously set list of numerical column names and finding the correlation with the 'loan_repaid' column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
numerical_feat_df = df.select_dtypes(include=['float64', 'int64'])
numerical_feat_df.corr().sort_values(by='loan_repaid')['loan_repaid'][:-1]
# Out:
# int_rate               -0.247758
# revol_util             -0.082373
# dti                    -0.062413
# loan_amnt              -0.059836
# installment            -0.041082
# open_acc               -0.028012
# pub_rec                -0.019933
# pub_rec_bankruptcies   -0.009383
# revol_bal               0.010892
# total_acc               0.017893
# annual_inc              0.053432
# mort_acc                0.073111
# Name: loan_repaid, dtype: float64

# %%
bar_plot = sns.barplot(numerical_feat_df.corr().sort_values(by='loan_repaid')['loan_repaid'][:-1])
bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=90)
# Out:
# C:\Users\niks8\AppData\Local\Temp\ipykernel_25892\3816360902.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=90)
# [Text(0, 0, 'int_rate'),
#  Text(1, 0, 'revol_util'),
#  Text(2, 0, 'dti'),
#  Text(3, 0, 'loan_amnt'),
#  Text(4, 0, 'installment'),
#  Text(5, 0, 'open_acc'),
#  Text(6, 0, 'pub_rec'),
#  Text(7, 0, 'pub_rec_bankruptcies'),
#  Text(8, 0, 'revol_bal'),
#  Text(9, 0, 'total_acc'),
#  Text(10, 0, 'annual_inc'),
#  Text(11, 0, 'mort_acc')]

# %% [markdown]
# ---
# ## 3. Data Cleaning and Preprocessing

# %% [markdown]
# ### 3.1 Missing Data
#
# **Exploring missing data in columns.**

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title               5.789208
# emp_length              4.621115
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.443401
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.069692
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# address                 0.000000
# loan_repaid             0.000000
# dtype: float64

# %% [markdown]
# ### 3.2 Processing 'Emp_title' and 'Emp_length'

# %%
df['emp_title'].value_counts()
# Out:
# emp_title
# Teacher                                   4389
# Manager                                   4250
# Registered Nurse                          1856
# RN                                        1846
# Supervisor                                1830
#                                           ...
# Electrical Controls Engineer                 1
# Nor-Com Inc                                  1
# Director of the Bach Society                 1
# customre services representative             1
# Director Bureau of Equipment Inventory       1
# Name: count, Length: 173105, dtype: int64

# %%
df.drop('emp_title', axis=1, inplace=True)

# %% [markdown]
# ### 3.2.1 Count plot for different categories in 'Emp_length'

# %%
plt.figure(figsize=(9, 3))
sns.countplot(data=df, palette="rainbow", x='emp_length', order=['< 1 year','1 year',
 '2 years',
 '3 years',
 '4 years',
 '5 years',
 '6 years',
 '7 years',
 '8 years',
 '9 years',
 '10+ years'])
# Out:
# C:\Users\niks8\AppData\Local\Temp\ipykernel_25892\2937782925.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, palette="rainbow", x='emp_length', order=['< 1 year','1 year',
# <Axes: xlabel='emp_length', ylabel='count'>

# %% [markdown]
# #### 3.2.2 Count plot of Employee length in relation to loan status

# %%
plt.figure(figsize=(9, 3))
sns.countplot(data=df, x='emp_length', order=['< 1 year','1 year',
 '2 years',
 '3 years',
 '4 years',
 '5 years',
 '6 years',
 '7 years',
 '8 years',
 '9 years',
 '10+ years'], hue='loan_status')
# Out:
# <Axes: xlabel='emp_length', ylabel='count'>

# %% [markdown]
# #### 3.2.3 Exploring Percentage of 'Charged-off' and 'Fully Paid' loan status, based on the above data visualization

# %%
emp_co = df[df['loan_status']=="Charged Off"].groupby("emp_length").count()['loan_status']
emp_fp = df[df['loan_status']=="Fully Paid"].groupby("emp_length").count()['loan_status']
emp_len = emp_co / (emp_co + emp_fp)

# %%
emp_len
# Out:
# emp_length
# 1 year       0.199135
# 10+ years    0.184186
# 2 years      0.193262
# 3 years      0.195231
# 4 years      0.192385
# 5 years      0.192187
# 6 years      0.189194
# 7 years      0.194774
# 8 years      0.199760
# 9 years      0.200470
# < 1 year     0.206872
# Name: loan_status, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.barplot(emp_len)
# Out:
# <Axes: xlabel='emp_length', ylabel='loan_status'>

# %%
df.drop('emp_length', axis=1, inplace=True)

# %% [markdown]
# ### 3.3 Rechecking Missing data

# %%
df.isna().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %% [markdown]
# ### 3.4 Checking the columns 'purpose' and 'title'

# %%
df['purpose'].head(10)
# Out:
# 0              vacation
# 1    debt_consolidation
# 2           credit_card
# 3           credit_card
# 4           credit_card
# 5    debt_consolidation
# 6      home_improvement
# 7           credit_card
# 8    debt_consolidation
# 9    debt_consolidation
# Name: purpose, dtype: object

# %%
df['title'].head(10)
# Out:
# 0                   Vacation
# 1         Debt consolidation
# 2    Credit card refinancing
# 3    Credit card refinancing
# 4      Credit Card Refinance
# 5         Debt consolidation
# 6           Home improvement
# 7       No More Credit Cards
# 8         Debt consolidation
# 9         Debt Consolidation
# Name: title, dtype: object

# %%
df.drop('title', axis=1, inplace=True)

# %% [markdown]
# ### 3.5 'Mortgage Accounts' Feature

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %%
df['mort_acc'].value_counts()
# Out:
# mort_acc
# 0.0     139777
# 1.0      60416
# 2.0      49948
# 3.0      38049
# 4.0      27887
# 5.0      18194
# 6.0      11069
# 7.0       6052
# 8.0       3121
# 9.0       1656
# 10.0       865
# 11.0       479
# 12.0       264
# 13.0       146
# 14.0       107
# 15.0        61
# 16.0        37
# 17.0        22
# 18.0        18
# 19.0        15
# 20.0        13
# 24.0        10
# 22.0         7
# 21.0         4
# 25.0         4
# 27.0         3
# 26.0         2
# 32.0         2
# 31.0         2
# 23.0         2
# 34.0         1
# 28.0         1
# 30.0         1
# Name: count, dtype: int64

# %%
numerical_feat_df.corr()['mort_acc'].sort_values()
# Out:
# int_rate               -0.082583
# dti                    -0.025439
# revol_util              0.007514
# pub_rec                 0.011552
# pub_rec_bankruptcies    0.027239
# loan_repaid             0.073111
# open_acc                0.109205
# installment             0.193694
# revol_bal               0.194925
# loan_amnt               0.222315
# annual_inc              0.236320
# total_acc               0.381072
# mort_acc                1.000000
# Name: mort_acc, dtype: float64

# %%
df.groupby('total_acc')['mort_acc'].mean()
# Out:
# total_acc
# 2.0      0.000000
# 3.0      0.052023
# 4.0      0.066743
# 5.0      0.103289
# 6.0      0.151293
#            ...
# 124.0    1.000000
# 129.0    1.000000
# 135.0    3.000000
# 150.0    2.000000
# 151.0    0.000000
# Name: mort_acc, Length: 118, dtype: float64

# %% [markdown]
# #### 3.5.2 Filling Missing Data in 'Mortgage accounts'

# %%
total_avg = df.groupby('total_acc')['mort_acc'].mean()

# %%
def fill_na(total_acc, mort_acc):
    """
    Replaces NaN values in mortage account with the average value from total_acc average series
    """
    if np.isnan(mort_acc):
        return total_avg[total_acc]
    else:
        return mort_acc

# %%
df['mort_acc'] = df.apply(lambda x: fill_na(x['total_acc'], x['mort_acc']), axis=1)

# %% [markdown]
# ### 3.6 Revisiting Missing data overall

# %%
df.isna().sum()
# Out:
# loan_amnt                 0
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# home_ownership            0
# annual_inc                0
# verification_status       0
# issue_d                   0
# loan_status               0
# purpose                   0
# dti                       0
# earliest_cr_line          0
# open_acc                  0
# pub_rec                   0
# revol_bal                 0
# revol_util              276
# total_acc                 0
# initial_list_status       0
# application_type          0
# mort_acc                  0
# pub_rec_bankruptcies    535
# address                   0
# loan_repaid               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# installment             0
# grade                   0
# sub_grade               0
# home_ownership          0
# annual_inc              0
# verification_status     0
# issue_d                 0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# address                 0
# loan_repaid             0
# dtype: int64

# %% [markdown]
# ### 3.7 Categorical Variables and Dummy Variables

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'earliest_cr_line',
#        'initial_list_status', 'application_type', 'address'],
#       dtype='object')

# %% [markdown]
# -----
# #### 3.7.1 term feature

# %%
df['term'].value_counts()
# Out:
# term
# 36 months    301247
# 60 months     93972
# Name: count, dtype: int64

# %%
df['term'] = df['term'].apply(lambda x: int(x.split()[0]))

# %%
df['term'].value_counts()
# Out:
# term
# 36    301247
# 60     93972
# Name: count, dtype: int64

# %% [markdown]
# #### 3.7.2 grade feature

# %%
df.drop('grade', axis=1, inplace=True)

# %% [markdown]
# #### 3.7.3 sub-grade feature

# %%
sub_grade_df = pd.get_dummies(df['sub_grade'], drop_first=True, dtype = int)
df = pd.concat([df, sub_grade_df], axis = 1)
df.drop('sub_grade', axis = 1, inplace=True)

# %% [markdown]
# #### 3.7.4 verification_status, application_type,initial_list_status, purpose features

# %%
dummy_cols_df = pd.get_dummies(df[['verification_status', 'application_type','initial_list_status','purpose']], drop_first=True, )
df = pd.concat([df, dummy_cols_df], axis=1)
df.drop(['verification_status', 'application_type','initial_list_status','purpose'], axis=1, inplace=True)

# %% [markdown]
# #### 3.7.5 home_ownership

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    198022
# RENT        159395
# OWN          37660
# OTHER          110
# NONE            29
# ANY              3
# Name: count, dtype: int64

# %%
df['home_ownership'] = df['home_ownership'].replace(['NONE', 'ANY'], 'OTHER')
home_owner_df = pd.get_dummies(df['home_ownership'], drop_first=True)
df = pd.concat([df, home_owner_df], axis = 1)

# %%
df.drop(columns = ['home_ownership'], axis = 1, inplace = True)

# %% [markdown]
# #### 3.7.6 address

# %%
df['zip_code'] = df['address'].apply(lambda address: address[-5:])

# %%
df['zip_code'].value_counts()
# Out:
# zip_code
# 70466    56880
# 22690    56413
# 30723    56402
# 48052    55811
# 00813    45725
# 29597    45393
# 05113    45300
# 11650    11210
# 93700    11126
# 86630    10959
# Name: count, dtype: int64

# %%
zip_code_df = pd.get_dummies(df['zip_code'], drop_first=True)
df = pd.concat([df, zip_code_df], axis = 1)
df.drop(columns = ['address', 'zip_code'], axis = 1, inplace= True)

# %% [markdown]
# #### 3.7.7 issue_d feature

# %%
feat_info('issue_d')
# Out:
# The month which the loan was funded

# %%
df.drop(columns=['issue_d'], axis = 1, inplace= True)

# %% [markdown]
# #### 3.7.8 earliest_cr_line

# %%
feat_info('earliest_cr_line')
# Out:
# The month the borrower's earliest reported credit line was opened

# %%
df['earliest_cr_line'].value_counts()
# Out:
# earliest_cr_line
# Oct-2000    3013
# Aug-2000    2930
# Oct-2001    2890
# Aug-2001    2879
# Nov-2000    2729
#             ...
# Feb-1957       1
# Jan-1953       1
# Oct-1961       1
# Aug-1962       1
# Aug-1959       1
# Name: count, Length: 684, dtype: int64

# %%
df['earliest_cr_line'] = df['earliest_cr_line'].apply(lambda date: int(date[-4:]))

# %%
df['earliest_cr_line'].value_counts()
# Out:
# earliest_cr_line
# 2000    29302
# 2001    29031
# 1999    26444
# 2002    25849
# 2003    23623
#         ...
# 1950        3
# 1951        3
# 1953        2
# 1944        1
# 1948        1
# Name: count, Length: 65, dtype: int64

# %% [markdown]
# ----
# ## 4. Regression Modelling
#
# ### 4.1 Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
df.drop(columns = ['loan_status'], axis = 1, inplace = True)

# %%
X = df.drop(columns = ['loan_repaid'], axis = 1)
y = df['loan_repaid'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# ### 4.2 Normalizing the Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ### 4.3 Model Definition

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model = Sequential()

model.add(Dense(78, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(39, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(19, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss='binary_crossentropy', optimizer = 'adam')

# %%
model.fit(x=X_train, y= y_train, epochs = 25, batch_size=256,
         validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3619 - val_loss: 0.2644
# Epoch 2/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2662 - val_loss: 0.2627
# Epoch 3/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2616 - val_loss: 0.2627
# Epoch 4/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2611 - val_loss: 0.2621
# Epoch 5/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2608 - val_loss: 0.2620
# Epoch 6/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2592 - val_loss: 0.2621
# Epoch 7/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2595 - val_loss: 0.2613
# Epoch 8/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2591 - val_loss: 0.2619
# Epoch 9/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2584 - val_loss: 0.2615
# Epoch 10/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.2588 - val_loss: 0.2616
# Epoch 11/25
# ...

# %%
model.save('lendingclub_regression.keras')

# %% [markdown]
# -----
#
# ## 5. Model Evaluation

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
loss_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 4.4 Model Predictions

# %%
predictions = model.predict(X_test)
predicted_class = (predictions > 0.5).astype("int32")
# Out:
# 2471/2471 ━━━━━━━━━━━━━━━━━━━━ 3s 989us/step

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test, predicted_class))
# Out:
# [[ 6899  8759]
#  [  131 63255]]

# %%
print(classification_report(y_test, predicted_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.44      0.61     15658
#            1       0.88      1.00      0.93     63386
#
#     accuracy                           0.89     79044
#    macro avg       0.93      0.72      0.77     79044
# weighted avg       0.90      0.89      0.87     79044

# %% [markdown]
# ----
#
# ## 6. Conclusion and Recommendations

# %%
import random
random.seed(101)
random_ind = random.randint(0,len(df))

new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]
new_customer
# Out:
# loan_amnt      25000.0
# term                60
# int_rate         18.24
# installment     638.11
# annual_inc     61665.0
#                 ...
# 30723             True
# 48052            False
# 70466            False
# 86630            False
# 93700            False
# Name: 305323, Length: 78, dtype: object

# %%
new_customer_scaled = scaler.transform(new_customer.values.reshape(1, 78))
# Out:
# d:\Coding\Git\Data-Science Projects\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
new_prediction  = model.predict(new_customer_scaled)
new_predicted_class = (new_prediction > 0.5).astype("int32")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step

# %%
new_predicted_class
# Out:
# array([[1]], dtype=int32)

# %%
df.iloc[random_ind]['loan_repaid']
# Out:
# np.int64(1)

# %% [markdown]
# It seems that the model was able to predict for this data point accurately. **The model has 89% accuracy overall.**
#
# ----
